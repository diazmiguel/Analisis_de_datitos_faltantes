# %% [markdown]
# ## Visualizaciones basicas
#
#  Creemos graficas rapidas para visualizar nuestros datos faltantes en nuestro data set

# %%
# %run 0.1-dataset.ipynb
# %run pandas-API.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Visualizacion por variable
datos.missing.missing_variable_plot()

# %%
# Por filas, observaciones
datos.missing.missing_case_plot()

# %% [markdown]
# Concluyendo nos graficamos el numero de datos daltantes para esa observacion,
#  1700 filas le faltan 15 variables, fuaa es mucho.

# %%
(
    datos
    .missing
    .missing_variable_span_plot(
        variable = 'maximo_nivel_de_estudios',
        span_every=500,
        rot = 0
    )
)

# %%
missingno.bar(df=datos);

# %%
missingno.matrix(df=datos);

# %% [markdown]
# Concluyendo: Podemos ver los valores faltantes para cada variable en columna.
#
#
# Ahora grafiquemos con upsetplot para algunas variables:

# %%
(
    datos
    .missing
    .missing_upsetplot(
        variables = ['pagos_en_dolares','dolarizado_cual_fue_el_ultimo_valor','pagos_en_criptomonedas','que_porcentaje_o_monto_recibis_en_criptomonedas'],
        element_size = 60
    )
)
# Out:
# {'matrix': <AxesSubplot:>,
#  'shading': <AxesSubplot:>,
#  'totals': <AxesSubplot:>,
#  'intersections': <AxesSubplot:ylabel='Intersection size'>}
