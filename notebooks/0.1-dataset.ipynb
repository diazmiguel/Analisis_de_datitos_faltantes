# %% [markdown]
# ## Cargamos nuestro Dataset
#
# Cargamos nuestros datos...

# %%
#Para recargar automaticamente el modulo
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Para cargar el modulo anterior
# %run 0.0-init.ipynb
# %run pandas-API.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
datos = pd.read_csv(
    filepath_or_buffer= ".././data/Encuesta de Remuneracion salarial Argentina.csv", 
    sep=",")

# %%
#datos.info()

# %% [markdown]
# Con esta rapida descripcion nos damos cuenta de que faltan varios datos en nuestro dataset. Por que la cantidad de datos por variable son 5764 y a varias columnas tienen datos nulos o NaN.
#  Veamos a continuacion algunos elementos de nuestro dataset:

# %%
datos.head(7)
# Out:
#   estoy_trabajando_en           donde_estas_trabajando dedicacion  \
# 0           Argentina                     Buenos Aires  Full-Time
# 1           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 2           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 3           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 4           Argentina                        Río Negro  Full-Time
# 5           Argentina                          Córdoba  Full-Time
# 6           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
#
#             tipo_de_contrato  \
# 0  Staff (planta permanente)
# 1  Staff (planta permanente)
# 2  Staff (planta permanente)
# 3  Staff (planta permanente)
# 4  Staff (planta permanente)
# 5  Staff (planta permanente)
# 6  Staff (planta permanente)
#
#    ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local  \
# 0                                           475480.0
# 1                                           260000.0
# ...

# %% [markdown]
#  Comprobamos que se importo correctamente la api de pandas Missing

# %%
datos.missing.number_missing()
# Out:
# 63731

# %%
datos.missing.number_complete()
# Out:
# 224469
