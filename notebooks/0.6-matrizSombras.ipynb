# %% [markdown]
# ## Pasos para crear una matriz de sombras
# 1. identificamos valores faltantes
# 2. reemplazamos los valores por su valor booleano
# 3. reemplazamos los valores por algo mas util e informativo
#
# Tabla original -> Tabla de sobra -> Tabla nubular

# %%
# %run 0.4-Codificacion.ipynb
# %run pandas-API.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
(
    datos_sustituidos[datos_sustituidos.columns[4:10]]
    .isna()
    .replace({
        False:'No perdido',
        True: 'Perdido'
    })
    .add_suffix("_NA")
    .pipe(
        lambda shadox_m : pd.concat(
            [datos_sustituidos[datos_sustituidos.columns[4:10]], shadox_m],
            axis ="columns"
        )
    )
)
# Out:
#       ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local  \
# 0                                              475480.0
# 1                                              260000.0
# 2                                              106350.0
# 3                                              339000.0
# 4                                              380000.0
# ...                                                 ...
# 5759                                           897000.0
# 5760                                           130000.0
# 5761                                           250000.0
# 5762                                           230000.0
# 5763                                           600000.0
#
#      ultimo_salario_mensual_o_retiro_neto_en_tu_moneda_local  \
# 0                                                396346
# 1                                                220000
# 2                                                 88560
# ...

# %%
(
    datos_sustituidos
    .missing.bind_shadow_matrix(only_missing=True)
    .groupby(['me_id_extra_NA'])['ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local']
    .describe()
    .reset_index()
)
# Out:
#   me_id_extra_NA   count           mean            std      min       25%  \
# 0        Missing   199.0  475991.760704  345728.796089  75000.0  221500.0
# 1    Not Missing  5565.0  435905.359863  302865.914339  68000.0  230000.0
#
#         50%       75%        max
# 0  379035.0  600000.0  1600000.0
# 1  350000.0  537000.0  1736000.0
